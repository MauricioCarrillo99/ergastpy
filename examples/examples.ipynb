# %% [markdown]
# <a href="https://colab.research.google.com/github/maxelOA/py_erpy2set/blob/main/examples/examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/maxelOA/py_erpy2set.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/maxelOA/py_erpy2set.git to /tmp/pip-req-build-7e8co_wv
#   Running command git clone --filter=blob:none --quiet https://github.com/maxelOA/py_erpy2set.git /tmp/pip-req-build-7e8co_wv
#   Resolved https://github.com/maxelOA/py_erpy2set.git to commit eaba37fdc09957692eda422d9bc6d0fe9a41947f
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for py-erpy2set: filename=py_erpy2set-1.0-py3-none-any.whl size=5016 sha256=3b1ebb4c0d2314c79bea9fd80e7df198804245ac62d4f9b3d94150b88c9d64e0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-25djzdux/wheels/6d/be/49/08e239006cae83941df4687da0810c2df61f8e3fe959b178fe
# Successfully built py-erpy2set
# ...

# %%
import erpy2set.f1_query as f1
import erpy2set.unravel as un
import json 
import requests
import pandas as pd

# %% [markdown]
#  # **UNRAVEL PACK**

# %% [markdown]
# ## unravel_noKey

# %% [markdown]
# Creamos un dataframe para la demostración de las funciones

# %%
url='http://ergast.com/api/f1/2022/results.json'
data=pd.DataFrame(requests.get(url).json()['MRData']['RaceTable']['Races'][0]['Results'])
data.head()
# Out:
#   number position positionText points  \
# 0     16        1            1     26
# 1     55        2            2     18
# 2     44        3            3     15
# 3     63        4            4     12
# 4     20        5            5     10
#
#                                               Driver  \
# 0  {'driverId': 'leclerc', 'permanentNumber': '16...
# 1  {'driverId': 'sainz', 'permanentNumber': '55',...
# 2  {'driverId': 'hamilton', 'permanentNumber': '4...
# 3  {'driverId': 'russell', 'permanentNumber': '63...
# 4  {'driverId': 'kevin_magnussen', 'permanentNumb...
#
#                                          Constructor grid laps    status  \
# 0  {'constructorId': 'ferrari', 'url': 'http://en...    1   57  Finished
# 1  {'constructorId': 'ferrari', 'url': 'http://en...    3   57  Finished
# 2  {'constructorId': 'mercedes', 'url': 'http://e...    5   57  Finished
# 3  {'constructorId': 'mercedes', 'url': 'http://e...    9   57  Finished
# ...

# %%
un.unravel_noKey(data).head()
# Out:
#   number position positionText points  Driver_driverId Driver_permanentNumber  \
# 0     16        1            1     26          leclerc                     16
# 1     55        2            2     18            sainz                     55
# 2     44        3            3     15         hamilton                     44
# 3     63        4            4     12          russell                     63
# 4     20        5            5     10  kevin_magnussen                     20
#
#   Driver_code                                         Driver_url  \
# 0         LEC       http://en.wikipedia.org/wiki/Charles_Leclerc
# 1         SAI      http://en.wikipedia.org/wiki/Carlos_Sainz_Jr.
# 2         HAM        http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3         RUS  http://en.wikipedia.org/wiki/George_Russell_%2...
# 4         MAG       http://en.wikipedia.org/wiki/Kevin_Magnussen
#
#   Driver_givenName Driver_familyName  ... grid laps    status Time_millis  \
# ...

# %% [markdown]
# ## unravel

# %%
url='http://ergast.com/api/f1/2022/results.json'
data=pd.DataFrame(requests.get(url).json()['MRData']['RaceTable']['Races'][0]['Results'])
data.head()
# Out:
#   number position positionText points  \
# 0     16        1            1     26
# 1     55        2            2     18
# 2     44        3            3     15
# 3     63        4            4     12
# 4     20        5            5     10
#
#                                               Driver  \
# 0  {'driverId': 'leclerc', 'permanentNumber': '16...
# 1  {'driverId': 'sainz', 'permanentNumber': '55',...
# 2  {'driverId': 'hamilton', 'permanentNumber': '4...
# 3  {'driverId': 'russell', 'permanentNumber': '63...
# 4  {'driverId': 'kevin_magnussen', 'permanentNumb...
#
#                                          Constructor grid laps    status  \
# 0  {'constructorId': 'ferrari', 'url': 'http://en...    1   57  Finished
# 1  {'constructorId': 'ferrari', 'url': 'http://en...    3   57  Finished
# 2  {'constructorId': 'mercedes', 'url': 'http://e...    5   57  Finished
# 3  {'constructorId': 'mercedes', 'url': 'http://e...    9   57  Finished
# ...

# %%
un.unravel(data,data['number'],'number').head()
# Out:
#   number position positionText points  Driver_driverId Driver_permanentNumber  \
# 0     16        1            1     26          leclerc                     16
# 1     55        2            2     18            sainz                     55
# 2     44        3            3     15         hamilton                     44
# 3     63        4            4     12          russell                     63
# 4     20        5            5     10  kevin_magnussen                     20
#
#   Driver_code                                         Driver_url  \
# 0         LEC       http://en.wikipedia.org/wiki/Charles_Leclerc
# 1         SAI      http://en.wikipedia.org/wiki/Carlos_Sainz_Jr.
# 2         HAM        http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3         RUS  http://en.wikipedia.org/wiki/George_Russell_%2...
# 4         MAG       http://en.wikipedia.org/wiki/Kevin_Magnussen
#
#   Driver_givenName Driver_familyName  ... grid laps    status Time_millis  \
# ...

# %% [markdown]
# ### **NOTE**

# %% [markdown]
# unravel and unravel_noKey makes changes in the own dataframe , that's the reason why we constanly define results table

# %% [markdown]
# ## it_contains

# %%
list1=['a','b']
list2=['c','d']
list3=['b','d']
list4=['a','b','c','d']

# %%
un.it_contains(list1,list2)
# Out:
# False

# %%
print(un.it_contains(list1,list3))
print(un.it_contains(list2,list3))
# Out:
# True
# True

# %%
un.it_contains(list4,list3)
# Out:
# True

# %% [markdown]
# ## contains_dict

# %%
url='http://ergast.com/api/f1/2022/results.json'
data=pd.DataFrame(requests.get(url).json()['MRData']['RaceTable']['Races'][0]['Results'])
data.tail(10)
# Out:
#    number position positionText points  \
# 10     47       11           11      0
# 11     18       12           12      0
# 12     23       13           13      0
# 13      3       14           14      0
# 14      4       15           15      0
# 15      6       16           16      0
# 16     27       17           17      0
# 17     11       18           18      0
# 18      1       19           19      0
# 19     10       20            R      0
#
#                                                Driver  \
# 10  {'driverId': 'mick_schumacher', 'permanentNumb...
# 11  {'driverId': 'stroll', 'permanentNumber': '18'...
# 12  {'driverId': 'albon', 'permanentNumber': '23',...
# 13  {'driverId': 'ricciardo', 'permanentNumber': '...
# 14  {'driverId': 'norris', 'permanentNumber': '4',...
# 15  {'driverId': 'latifi', 'permanentNumber': '6',...
# 16  {'driverId': 'hulkenberg', 'permanentNumber': ...
# 17  {'driverId': 'perez', 'permanentNumber': '11',...
# ...

# %%
un.contains_dict(data['number'])
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
un.contains_dict(data['Time'])
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False]

# %% [markdown]
# # **f1_query pack**

# %%
f1.raw_table('qualifyingResults',2022)
# Out:
#    number position  Driver_driverId Driver_permanentNumber Driver_code  \
# 0      16        1          leclerc                     16         LEC
# 1       1        2   max_verstappen                     33         VER
# 2      55        3            sainz                     55         SAI
# 3      11        4            perez                     11         PER
# 4      44        5         hamilton                     44         HAM
# ..    ...      ...              ...                    ...         ...
# 15     20       16  kevin_magnussen                     20         MAG
# 16     10       17            gasly                     10         GAS
# 17     77       18           bottas                     77         BOT
# 18     23       19            albon                     23         ALB
# 19      6       20           latifi                      6         LAT
#
#                                         Driver_url Driver_givenName  \
# ...

# %%
f1.clean_table('qualifyingResults',2022)
# Out:
#     raceId         driverId constructorId number position        Q1        Q2  \
# 0        1          leclerc       ferrari     16        1  1:31.471  1:30.932
# 1        1   max_verstappen      red_bull      1        2  1:31.785  1:30.757
# 2        1            sainz       ferrari     55        3  1:31.567  1:30.787
# 3        1            perez      red_bull     11        4  1:32.311  1:31.008
# 4        1         hamilton      mercedes     44        5  1:32.285  1:31.048
# ..     ...              ...           ...    ...      ...       ...       ...
# 15      22  kevin_magnussen          haas     20       16  1:25.834       NaN
# 16      22            gasly    alphatauri     10       17  1:25.859       NaN
# 17      22           bottas          alfa     77       18  1:25.892       NaN
# 18      22            albon      williams     23       19  1:26.028       NaN
# 19      22           latifi      williams      6       20  1:26.054       NaN
#
#           Q3
# 0   1:30.558
# ...

# %%
f1.query_range('qualifyingResults',2021,2022)
# Out:
#     raceId         driverId constructorId number position        Q1        Q2  \
# 0        1   max_verstappen      red_bull     33        1  1:30.499  1:30.318
# 1        1         hamilton      mercedes     44        2  1:30.617  1:30.085
# 2        1           bottas      mercedes     77        3  1:31.200  1:30.186
# 3        1          leclerc       ferrari     16        4  1:30.691  1:30.010
# 4        1            gasly    alphatauri     10        5  1:30.848  1:30.513
# ..     ...              ...           ...    ...      ...       ...       ...
# 15      22  kevin_magnussen          haas     20       16  1:25.834       NaN
# 16      22            gasly    alphatauri     10       17  1:25.859       NaN
# 17      22           bottas          alfa     77       18  1:25.892       NaN
# 18      22            albon      williams     23       19  1:26.028       NaN
# 19      22           latifi      williams      6       20  1:26.054       NaN
#
#           Q3
# 0   1:28.997
# ...

# %% [markdown]
# ## num_races

# %%
f1.num_races(2010)
# Out:
# 19

# %%
f1.num_races(2022)
# Out:
# 22

# %% [markdown]
# ## max_laps

# %%
f1.max_laps(2022,22)
# Out:
# 58

# %% [markdown]
# ## firstCap

# %%
'constructorResults'.capitalize()
# Out:
# 'Constructorresults'

# %%
f1.firstCap('constructorResults')
# Out:
# 'ConstructorResults'

# %% [markdown]
# ## full_chema

# %% [markdown]
# laps table takes more time of retreivieng than the others table, please be patience

# %%
schema=f1.full_schema(2021,2022)
# Out:
# table seasons is ready
# table drivers is ready
# table constructors is ready
# table circuits is ready
# table status is ready
# table races is ready
# table results is ready
# table qualifyingResults is ready
# table constructorResults is ready
# table constructorStandings is ready
# table driverStandings is ready
# table pitstops is ready
# table laps is ready
# full success at retrieving the schema

# %%
schema.keys()
# Out:
# dict_keys(['seasons', 'drivers', 'constructors', 'circuits', 'status', 'races', 'results', 'qualifyingResults', 'constructorResults', 'constructorStandings', 'driverStandings', 'pitstops', 'laps'])

# %%
schema['constructorStandings'].head()
# Out:
#    raceId constructorId points position positionText wins
# 0       1      mercedes     41        1            1    1
# 1       1      red_bull     28        2            2    0
# 2       1       mclaren     18        3            3    0
# 3       1       ferrari     12        4            4    0
# 4       1    alphatauri      2        5            5    0

# %%
schema['seasons']
# Out:
#   season                                                url
# 0   2021  http://en.wikipedia.org/wiki/2021_Formula_One_...
# 0   2022  http://en.wikipedia.org/wiki/2022_Formula_One_...
